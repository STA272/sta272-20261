# %% [markdown]
# # Week 1 homework
#
# ## Purpose of Homework
#
# Welcome to your first weekly homework assignment! This is homework will not count toward your grade, but you should complete it test out the workflow.
#
# You are encouraged to refer to lecture content and liberally use course resources such as the discussion board and office hours.
#
# ## Logistics
#
# Due date: The homework is due 12:00pm on Thursday, January 15, 2026.
#
# You will submit your homework on [MarkUs](https://markus.teach.cs.toronto.edu/markus/).
#
# 1. Download this file (`sta272_a1.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the hw1 assignment. (See [our MarkUs Guide](../guides/markus_guide.ipynb) for detailed instructions.)
#
# All homeworks will take place in a Jupyter notebook (like this one). When you are done, you will download this notebook and submit it to MarkUs.

# %% [markdown]
# ## Question 1: Filling in some Python code
#
# In the cell below, replace the ellipsis `(...)` with the number of courses you're taking this semester.

# %%
num_courses = ...  # Replace the ... with your number of courses

# We've provided this code to check your work. Try running this cell!
print(f"You are taking {num_courses} course(s).")

# %% [markdown]
# You should see something like You are taking 5 course(s). in the output when you run the cell.
#
# Next, we have two new variables, first_name and last_name. Replace each `...` with your first and last name, respectively.
#
# Be sure to surround your name with quotes, e.g. `"David"`, not just `David`. This tells Python that your name should be interpreted as data (i.e., a name) rather than code or a variable.

# %%
first_name = ...  # Replace the ... with your first name, surrounded by quotes
last_name = ...   # Replace the ... with your last name, surrounded by quotes

# We've provided this code to check your work. Try running this cell!
print(f"Hello {first_name} {last_name}, and welcome to STA272!")

# %% [markdown]
# Did you see a welcome message with your name appear? If not, please ask for help if you get stuck!

# %% [markdown]
# ## Question 2: A bit of computing
#
# Count the number of words in the following paragraph.
#
# > Statistical Models use real, empirical data, handle uncertainty, focus on patterns and predictions (e.g., linear regression).
#
#
# ### Step 1
#
# Store the text below as a string in `"model_text"`.
#
# ### Step 2
#
# Count the number of words in `"model_text"` and store the result in another variable called `num_words`.
#
# HINT: use [`string.split()`](https://docs.python.org/3.6/library/stdtypes.html#str.split) &#x1F448; click to see Python documentation.

# %%
model_text = ...

num_words = ...

# We've provided this code to check your work. Try running this cell!
print(f"The number of words in model_text is {num_words}.")

# %% [markdown]
# # Question 3: Written Response
#
# Finally, we want to give you practice using Markdown to create text inside a Jupyter notebook.
#
# Create a new Markdown cell (as described in the JupyterHub Guide), and inside the cell write answers to the following questions:
#
# 1. What kinds of data are you interested in working with this semester?
#
# 2. What are you looking forward to in STA272?

# %% [markdown]
# 1. lots of data
# 2. learning to understand data
