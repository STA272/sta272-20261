# %% [markdown]
# ## STA272 Lab #1

# %% [markdown]
# ## Purpose of Lab
#
# Welcome to your first weekly tutorial lab!
#
# You are encouraged to refer to lecture content and liberally use course resources.
#
# ## Logistics
#
# Due date: The homework is due **11:59pm on Thursday, January 15, 2026.**
#
# You will submit your homework on [MarkUs](https://markus.teach.cs.toronto.edu/markus/).
#
# 1. Download this file (`sta272_lab1.ipynb`) from JupyterHub. (See [our JupyterHub Guide](../guides/jupyterhub_guide.ipynb) for detailed instructions.)
# 2. Submit this file to MarkUs under the hw1 assignment. (See [our MarkUs Guide](../guides/markus_guide.ipynb) for detailed instructions.)

# %% [markdown]
# ## Analysis of Popular Social Platforms
#
# <https://en.wikipedia.org/wiki/List_of_most_popular_social_platforms> has a list of the most popular social platforms (at least 100 million users).
#
# ### Task #1
#
# Read `expected_social100.csv` into a `pandas` dataframe called `social100_df`.
#
# The code cells below contains starter code. Fill in the ellipsis `(...)` with the r

# %%
# fill in your answer for Task#1 in this cell

import pandas as pd


social100_df = pd.read_csv(...)

#check your work
social100_df.head()

# %% [markdown]
# ### Task #2
# Clean the column labelled Monthly active users.  In `social100_df` store the values as a `float` in units of billions. For example, Douyin has 755 million users which should be stored as 0.755. Store this column in a variable called `active_users_float`.

# %%
# fill in your answer for Task#2 in this cell

active_users_float = (... .
    astype(...).
    str.extract(r'([\d.]+)', expand=False).
    astype(...))

# %% [markdown]
# ### Task #3
#
# The units of this column are either in millions of billions. Create a boolean variable called `billion` that is `True` if the users are recorded in billions or `False` if recorded in millions.
#
# (Hint: use the values of `active_users_float`).

# %%
# fill in your answer for Task#3 in this cell

billion = active_users_float < ...

# %% [markdown]
# ### Task #4
#
# Some values of `active_users` are in billions and some values are in millions.  Create a new variable `active_users_units` whose values are `active_users` in billions.  This can be done by dividing values that are in the millions in `active_users` by 1000, since 1000 x 1 million = 1 billion.

# %%
# fill in your answer for Task#4 in this cell

active_users_units = active_users_float.where(..., ...)

# %% [markdown]
# ### Task #5
#
# Create a new dataframe called `social100_df2` that includes columns: `active_users_float`, `billion`, and `active_users_units`.

# %%
# fill in your answer for Task#5 in this cell

social100_df2 = ...

social100_df2[...] = ...

social100_df2[...] = ...

social100_df2[...] = ...
